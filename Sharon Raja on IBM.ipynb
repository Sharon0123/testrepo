# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **SHARON RAJA** \
# A Data Scientist & A Son of God

# %% [markdown]
# _I am interested in Data Science. Because, It is the Sexiest job in the &nbsp; $21^{st}$ Century… And I’m interested in Business and Statistics. And I’m interested of gaining insights from Data… So, To choose Data Science is the Best for my Job._

# %% [markdown]
# ### Cube value of 3

# %%
3**3
# Out:
# 27

# %% [markdown]
# **<a href="sharon/raja">Hi... &nbsp; I'm Sharon Raja...</a>** \
# **<a href="tools.for/data.science"> &emsp; Hello…! &nbsp; How are You all of My Peers…?</a>** \
# **<a href="studies/learning.go"> &emsp; &emsp; How is going on there Your Studies & Learnings..?</a>**
#
# <h3 align="center"> Hyperlinks </h3>
#
# *<a href="https://www.datacamp.com/tutorial/markdown-in-jupyter-notebook">Markdown Tutorial &nbsp;</a>* \
# *<a href="https://www.google.com" >Go to Google</a>*
#
# <h3 align="center"> Image </h3>
#
# <a href="https://images.news18.com/ibnlive/uploads/2022/01/jupiter-like-planet-16423911223x2.png?im=Resize,width=360,aspect=fit,type=normal?im=Resize,width=320,aspect=fit,type=normal" >View</a>
#
# ![image.png](attachment:1408e1de-ecf7-4870-9f47-89a5890e2989.png)
#
#  <h3 align="center"> Bulleted list </h3>
#
# **What is Data Science..?**
# * Data science is something that or what data scientists Do.
# * Data Science is which helps physicians to provide the best treatment for their patients, and helps meteorologists to predict the extent of local weather events, and can even help to predict natural disasters like earthquakes and tornadoes.
#
# * Data Science is the project to communicate new information and insights from the data analysis to key decision-makers.
#
# * Data science is that which will result in excluding hundreds of thousands of individuals who have recently turned to the emerging field.
#
# * Data science is the study of large quantities of data, which can reveal insights that help organizations to make strategic choices.
#
# <h3 align="center"> Blocked Quotes </h3>
#
# > Our Indian Scientist, **Dr. APJ Abdul Kalam** said about _God_ and about the _Prayer_,
# >> "**_God_**, our _Creater_, has stored within our minds and personalities, great potential strength and ability. **_Prayer_** helps us tap and develop these _powers_."
#
# > and, He said about our _Job_ and our _Company_,
# >> "Love your **_Job_** but don't love your **_Company_**, because you may not know when your company stops loving YOU"
#
#
# <h3 align="center"> Numbered list </h3>
#
# $ Components$ &ensp; $of$ &nbsp; $a$ &nbsp; $Report: $
# 1.  Cover page
# 2.  Table of Contents
# 3.  Executive Summary
# 4.  References Section
# 5.  Introductory Section
# 6.  Methodology Section
# 7.  Discussion Section
# 8.  Results Section
# 9.  Conclusion Section
# 10.  Acknowledgment Section
#
# <h3 align="center"> Horizontal Rules & Tables </h3>
#
# | Items |Rate| Qnty | Amount |
# |:-| -|:-:|-:|
# | **Biscuits** |49 |75 |  3,675 |
# | **Cakes** | 26 | 150 |  3,900 |
# | **Vegetables** | 250 | 3 |  750 |
# |**Food** | 459|25 |  11,475 |
# | **Furniture** | 3599 | 5 |  17,995|
# | **_Total_** |||  **_37,795_**|
#
#  <h3 align="center"> Code / Syntax Highlighting & Horizontal Rules </h3>
#
# &emsp; &emsp; &emsp; &#9632; &#9711; &#9650; &emsp; - $TREE$ - &emsp; &#9650; &#9711; &#9632;
#
# _Do not cut me,\
# &emsp; Cried the `tree`.\
# Because I give you\
# &emsp; Rain `free`._
#
# _In my cool shade\
# &emsp; You `rest`,\
# Eat my Fruits\
# &emsp; That are `best`._
#
# _Take in my fresh\
# &emsp; `Smell`,\
# Let me live\
# &emsp; My life `well`._
#
# <h3 align="center"> Horizontal Rules,  Strikethrough  & Tables </h3>
#
#
# ##### Working with Version Control
#
# | Final List|
# |:-:|
# | **Milk** |
# |~~Curd~~|
# | Sugar |
# |~~Eggs~~|
# | **Flour** |
# |~~Ghee~~|
# | **Butter**|
# |~~Coffee~~|
# |**Biscuits**|
